# %%
# %matplotlib inline
from PIL import  Image
im = Image.open('/root/lena4.jpg')
print im.getbands()
print im.size
im = im.resize((28,28))
 
im = im.convert('L')
im.save("/root/lena4.jpg")

print im.size
#im = im.convert('L')
# Out:
# ('L',)
# (28, 28)
# (28, 28)

# %%
import  matplotlib.pyplot as plt
im2 = plt.imread('/root/lena5.jpg')
plt.imshow(im2)
plt.show()
